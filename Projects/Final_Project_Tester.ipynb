# %%
import numpy as np
from scipy import stats

# %%
# sample_1 = np.array([412,387,423,398,441,375,409,432])
# sample_2 = np.array([143,97,118,86,152,109,131,94])


# sample_1 = np.array([2.6, 2.6, 2.4, 2.6, 2.4, 2.4, 2.4, 2.6, 2.4, 2.6])
# sample_2 = np.array([2.4, 2.4, 2.4, 2.4, 2.4, 2.4, 2.4, 2.4, 2.4, 2.4])

# sample_1 = np.array([99.76, 102.67, 104, 98.97, 102.2, 90.04, 93.33, 100.54,73.93,109.26,106.47,92.86,80.65,99.15])
                     
                     
# sample_2 = np.array([115.63,101.79,114.64,114.19,112.41,110.7,113.77,81.55,65.92,68.18,40.17,38.19,39.21,48.53])

# sample_1 = np.array([3, 4, 2, 5, 4, 6])
# sample_2 = np.array([37,38,36,36,36,37])

# sample_1 = np.array([12.91, 12.04, 12.06, 10.67, 12.33, 9.69, 10.01, 9.91, 9.22, 8.87])
# sample_2 = np.array([10.12, 15.98, 12.02, 9.95, 12.04, 10.81, 9.75, 10.92, 9.22, 9.94])

# sample_1 = np.array([2014,2185,2335,2380,2498])
# sample_2 = np.array([3612,4046,4181,4211,4277])

# sample_1 = np.array([308, 309, 315, 304, 327, 271, 352, 240, 233, 272, 263, 268, 280, 220,256, 246, 204, 208, 362, 245])
# sample_2 = np.array([304, 308, 302, 290, 295, 219, 256, 315, 251, 257, 240, 202, 212, 214, 223, 227, 260, 306, 219, 251])

# sample_1 = np.array([0.59, 0.72, 0.40, 0.63, 0.59, 0.41, 0.68, 0.5, 0.59, 0.64])
# sample_2 = np.array([1.62, 1.04, 1.79, 1.25, 1.33, 2.17, 1.79, 2.17, 1.96, 2.12])

# sample_1 = np.array([18.2, 17.5, 19.1, 18.7, 17.9, 18.4, 19.3, 17.8, 18.6, 18.9])
# sample_2 = np.array([31.4, 33.2, 30.8, 32.1, 34.0, 31.7, 32.9, 33.5, 30.9, 32.4])

sample_1 = np.array([6, 3, 6, 11, 3, 0, 6, 5, 13, 8,3,5,11,9,12])
sample_2 = np.array([1,2,2,2,4,1,3,4,3,5,1,6,4,4,4])

n1 = np.shape(sample_1)[0]
n2 = np.shape(sample_2)[0]

print(n1)
print(n2)
# Out:
# 15
# 15

# %%
print("Mean1: ",np.mean(sample_1))
print("Mean2: ",np.mean(sample_2))

print("Std1: ",np.std(sample_1,ddof = 1))
print("Std2: ",np.std(sample_2,ddof = 1))
# Out:
# Mean1:  6.733333333333333
# Mean2:  3.066666666666667
# Std1:  3.8259763770958175
# Std2:  1.533747356112131

# %%
stats.ttest_ind(sample_1, sample_2, axis=0, equal_var=False, nan_policy='propagate', alternative='two-sided', trim=0, method=None, keepdims=False)
# Out:
# TtestResult(statistic=np.float64(3.4451987778405586), pvalue=np.float64(0.0028167034996347136), df=np.float64(18.386394528629047))
